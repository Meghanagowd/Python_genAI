# %% [markdown]
# DAY 1

# %% [markdown]
# TASK 1: PRINTING USING PRINT FUNC

# %%
print("hello")
print("This is Meghana")
print("welcome to python and genAI learning")
# Out:
# hello
# This is Meghana
# welcome to python and genAI learning

# %% [markdown]
# TASK 2: VARIABLE TYPE SWITCHING

# %% [markdown]
# int to float

# %%
a = 10
a=float(a)
print(a)
print(type(a))
# Out:
# 10.0
# <class 'float'>

# %% [markdown]
#  float into str

# %%
a = 2.5
a = str(a)
print(a)
print(type(a))
# Out:
# 2.5
# <class 'str'>

# %% [markdown]
# string to int

# %%
a = "10"
a  = int(a)
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %% [markdown]
# TASK 3 : TYPE CHECKING SYSTEM

# %%
a = 10 
print(type(a))
# Out:
# <class 'int'>

# %%
a = 1.1
print(type(a))
# Out:
# <class 'float'>

# %%
a = "Meghana"
print(type(a))
# Out:
# <class 'str'>

# %%
a = True
print(type(a))
# Out:
# <class 'bool'>

# %% [markdown]
#  TASK 4 : TYPECASTING EDGE CASES

# %%
a = "2"
print(int(a))
# Out:
# 2

# %%
a = "2.5"
print(float(a))
# Out:
# 2.5

# %%
a = "abc"
print(int(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 a = "abc"
# ----> 2 print(int(a))
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
a = "aba"
print(float(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 a = "aba"
# ----> 2 print(float(a))
#
# ValueError: could not convert string to float: 'aba'

# %% [markdown]
# Task 5 : String Indexing Practice

# %%
a = "Python"
print(a[0])
print(a[len(a)-1])
print(a[int(len(a)/2)])
# Out:
# P
# n
# h

# %% [markdown]
# TASK 6 : CONCATENATION

# %%
print( "5" + "2")
# Out:
# 52

# %%
print(5+2)
# Out:
# 7

# %%
print("5"+2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print("5"+2)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# TASK 7 : LENGTH FUNCTION PRACTICE

# %%
name = "Meghana"
print(len(name))
# Out:
# 7

# %%
a = ""
print(len(a))
# Out:
# 0
